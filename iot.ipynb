# %%
import pandas as pd
import matplotlib.pylab as plt
from pandas import DataFrame

# %%
data = pd.read_csv("Data.csv")

# %%
data.head()
# Out:
#             Timestamp  Ambient_Temp  Probe_Temp  Humidity
# 0  11/28/2020 5:57 PM          22.1        22.8        74
# 1  11/28/2020 5:42 PM          22.3        22.9        75
# 2  11/28/2020 5:27 PM          22.6        23.2        74
# 3  11/28/2020 5:12 PM          22.6        23.3        74
# 4  11/28/2020 4:57 PM          22.8        23.5        74

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3c9a60fd698f> in <module>
# ----> 1 df.count()
#
# NameError: name 'df' is not defined

# %%
X = [i+1 for i in range(len(data['Humidity']))]

# %%
df1 = data[711:0:-1]
X = [i+1 for i in range(len(df1['Humidity']))]
y =  df1['Humidity']

# %%
plt.style.use(['dark_background'])
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([1, 1, 1, 1])
plt.plot(X,y)
plt.title('HUMIDITY CHANGE OVER A PERIOD OF ONE WEEK',fontsize = 30)
plt.xlabel('DATE',fontsize = 20)
plt.ylabel('HUMIDITY',fontsize = 20)
#plt.xticks(dates)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
ax.set_xticks([62,153,245,331,421,510,610,695])
ax.set_xticklabels(['21 Nov','22 Nov', '23 Nov', '24 Nov', '25 Nov','26 Nov','27 Nov','28 Nov'])

#plt.xlim(0,450)
#plt.ylim(0,30)
plt.show()

# %%
df1 = data[711:0:-1]
X = [i+1 for i in range(len(df1['Humidity']))]
y =  df1['Probe_Temp']

# %%
plt.style.use(['dark_background'])
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([1, 1, 1, 1])
plt.plot(X,y)
plt.title('TEMPERATURE CHANGE OVER A PERIOD OF ONE WEEK',fontsize = 30)
plt.xlabel('DATE',fontsize = 20)
plt.ylabel('TEMPERATURE',fontsize = 20)
#plt.xticks(dates)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
ax.set_xticks([62,153,245,331,421,510,610,695])
ax.set_xticklabels(['21 Nov','22 Nov', '23 Nov', '24 Nov', '25 Nov','26 Nov','27 Nov','28 Nov'])

#plt.xlim(0,450)
#plt.ylim(0,30)
plt.show()

# %%
df1 = data[711:0:-1]
X = [i+1 for i in range(len(df1['Humidity']))]
y =  df1['Ambient_Temp']

# %%
df1.head()
# Out:
#                Timestamp  Ambient_Temp  Probe_Temp  Humidity
# 711  11/20/2020 11:34 PM          21.8        21.7        66
# 710  11/20/2020 11:49 PM          21.8        21.7        66
# 709  11/21/2020 12:05 AM          21.8        21.6        67
# 708  11/21/2020 12:20 AM          21.6        21.4        67
# 707  11/21/2020 12:35 AM          21.6        21.2        67

# %%
plt.style.use(['dark_background'])
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([1, 1, 1, 1])
plt.plot(X,y)
plt.title('TEMPERATURE CHANGE OVER A PERIOD OF ONE WEEK',fontsize = 30)
plt.xlabel('DATE',fontsize = 20)
plt.ylabel('TEMPERATURE',fontsize = 20)
#plt.xticks(dates)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
ax.set_xticks([62,153,245,331,421,510,610,695])
ax.set_xticklabels(['21 Nov','22 Nov', '23 Nov', '24 Nov', '25 Nov','26 Nov','27 Nov','28 Nov'])

#plt.xlim(0,450)
#plt.ylim(0,30)
plt.show()

# %%
df = data[618:522:-1]

# %%
df.head()
# Out:
#                Timestamp  Ambient_Temp  Probe_Temp  Humidity
# 618  11/21/2020 11:09 PM          21.8        21.6        51
# 617  11/21/2020 11:24 PM          21.7        21.4        52
# 616  11/21/2020 11:39 PM          21.7        21.3        53
# 615  11/21/2020 11:54 PM          21.6        21.2        54
# 614  11/22/2020 12:09 AM          21.6        21.0        54

# %%
df.tail()
# Out:
#                Timestamp  Ambient_Temp  Probe_Temp  Humidity
# 527  11/22/2020 11:01 PM          21.8        21.8        56
# 526  11/22/2020 11:16 PM          21.8        21.8        57
# 525  11/22/2020 11:31 PM          21.8        21.6        57
# 524  11/22/2020 11:46 PM          21.6        21.6        58
# 523  11/23/2020 12:01 AM          21.6        21.4        59

# %%
df.count
# Out:
# <bound method DataFrame.count of                Timestamp  Ambient_Temp  Probe_Temp  Humidity
# 618  11/21/2020 11:09 PM          21.8        21.6        51
# 617  11/21/2020 11:24 PM          21.7        21.4        52
# 616  11/21/2020 11:39 PM          21.7        21.3        53
# 615  11/21/2020 11:54 PM          21.6        21.2        54
# 614  11/22/2020 12:09 AM          21.6        21.0        54
# ..                   ...           ...         ...       ...
# 527  11/22/2020 11:01 PM          21.8        21.8        56
# 526  11/22/2020 11:16 PM          21.8        21.8        57
# 525  11/22/2020 11:31 PM          21.8        21.6        57
# 524  11/22/2020 11:46 PM          21.6        21.6        58
# 523  11/23/2020 12:01 AM          21.6        21.4        59
#
# [96 rows x 4 columns]>

# %%
X = df['Timestamp']
X1 = [i+1 for i in range(len(df['Humidity']))]
y1 =  df['Humidity']

# %%
plt.style.use(['dark_background'])
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([1, 1, 1, 1])
plt.plot(X1,y1)
plt.title('HUMIDITY CHANGE OVER A SINGLE DAY',fontsize = 30)
plt.xlabel('TIME',fontsize = 20)
plt.ylabel('HUMIDITY',fontsize = 20)
#plt.xticks(dates)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
ax.set_xticks([12,24,36,48,60,72,84,96])
ax.set_xticklabels(['12 AM', '3 AM', '6 AM', '9 AM','12 PM','3 PM','6 PM','9 PM'])

#plt.xlim(0,450)
#plt.ylim(0,30)
plt.show()

# %%
X = df['Timestamp']
X1 = [i+1 for i in range(len(df['Humidity']))]
y1 =  df['Probe_Temp']

# %%
plt.style.use(['dark_background'])
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([1, 1, 1, 1])
plt.plot(X1,y1)
plt.title('TEMPERATURE CHANGE OVER A SINGLE DAY',fontsize = 30)
plt.xlabel('TIME',fontsize = 20)
plt.ylabel('TEMPERATURE',fontsize = 20)
#plt.xticks(dates)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
ax.set_xticks([12,24,36,48,60,72,84,96])
ax.set_xticklabels(['12 AM', '3 AM', '6 AM', '9 AM','12 PM','3 PM','6 PM','9 PM'])

#plt.xlim(0,450)
#plt.ylim(0,30)
plt.show()

# %%
#X1 = df['Timestamp']
#X1 = [i+1 for i in range(len(df['Humidity']))]
y_temp1 =  df['Probe_Temp']

# %%
plt.style.use(['dark_background'])
#plt.figure(figsize=(20,6))
plt.plot(X1,y_temp1)
plt.title('Temperature Change over a Day')
plt.xlabel('Time of Day')
plt.ylabel('Humidity')
#plt.xlim(0,450)
#plt.ylim(0,30)
plt.show()
